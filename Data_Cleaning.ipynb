# %%
#Data set for Luxury Housing Sales Analysis –Bengaluru

import pandas as pd
import numpy as np

# %%
#Loading the data from CSV file
df=pd.read_csv(r"D:\Project_2\Data\Luxury_Housing_Bangalore.csv")
df
# Out:
#        Property_ID       Micro_Market Project_Name Developer_Name  \
# 0       PROP000001      Sarjapur Road    Project_0            RMZ
# 1       PROP000002        Indiranagar    Project_1    Puravankara
# 2       PROP000003  Bannerghatta Road    Project_2   Tata Housing
# 3       PROP000004       bellary road    Project_3        Embassy
# 4       PROP000005        Koramangala    Project_4        SNN Raj
# ...            ...                ...          ...            ...
# 100995  PROP004730       BELLARY ROAD  Project_229        Embassy
# 100996  PROP059810       Bellary Road  Project_309        Brigade
# 100997  PROP065099        HENNUR ROAD   Project_98            RMZ
# 100998  PROP093022        rajajinagar   Project_21        Embassy
# 100999  PROP023826         whitefield  Project_325     L&T Realty
#
#         Unit_Size_Sqft Configuration     Ticket_Price_Cr Transaction_Type  \
# 0               4025.0          4bhk  12.750846039118798          Primary
# ...

# %%
df.shape
# Out:
# (101000, 18)

# %%
df.columns
# Out:
# Index(['Property_ID', 'Micro_Market', 'Project_Name', 'Developer_Name',
#        'Unit_Size_Sqft', 'Configuration', 'Ticket_Price_Cr',
#        'Transaction_Type', 'Buyer_Type', 'Purchase_Quarter',
#        'Connectivity_Score', 'Amenity_Score', 'Possession_Status',
#        'Sales_Channel', 'NRI_Buyer', 'Locality_Infra_Score',
#        'Avg_Traffic_Time_Min', 'Buyer_Comments'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Property_ID              object
# Micro_Market             object
# Project_Name             object
# Developer_Name           object
# Unit_Size_Sqft          float64
# Configuration            object
# Ticket_Price_Cr          object
# Transaction_Type         object
# Buyer_Type               object
# Purchase_Quarter         object
# Connectivity_Score      float64
# Amenity_Score           float64
# Possession_Status        object
# Sales_Channel            object
# NRI_Buyer                object
# Locality_Infra_Score    float64
# Avg_Traffic_Time_Min      int64
# Buyer_Comments           object
# dtype: object

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 100995     True
# 100996     True
# 100997     True
# 100998     True
# 100999     True
# Length: 101000, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# Property_ID                 0
# Micro_Market                0
# Project_Name                0
# Developer_Name              0
# Unit_Size_Sqft           9957
# Configuration               0
# Ticket_Price_Cr          9913
# Transaction_Type            0
# Buyer_Type                  0
# Purchase_Quarter            0
# Connectivity_Score          0
# Amenity_Score           10000
# Possession_Status           0
# Sales_Channel               0
# NRI_Buyer                   0
# Locality_Infra_Score        0
# Avg_Traffic_Time_Min        0
# Buyer_Comments          18099
# dtype: int64

# %%
# Remove 'Cr', 'Rs', '₹', and extra spaces
df['Ticket_Price_Cr'] = df['Ticket_Price_Cr'].str.replace(r'(Cr|Rs|₹)', '', regex=True).str.strip()

# Convert to numeric (float), coercing errors to NaN(raise,ignore)
df['Ticket_Price_Cr'] = pd.to_numeric(df['Ticket_Price_Cr'], errors='coerce')

# %%
df
# Out:
#       Property_ID       Micro_Market Project_Name Developer_Name  \
# 0      PROP000001      Sarjapur Road    Project_0            RMZ
# 1      PROP000002        Indiranagar    Project_1    Puravankara
# 2      PROP000003  Bannerghatta Road    Project_2   Tata Housing
# 3      PROP000004       bellary road    Project_3        Embassy
# 4      PROP000005        Koramangala    Project_4        SNN Raj
# ...           ...                ...          ...            ...
# 99995  PROP099996       bellary road  Project_495     L&T Realty
# 99996  PROP099997          YELAHANKA  Project_496     L&T Realty
# 99997  PROP099998        rajajinagar  Project_497       Prestige
# 99998  PROP099999        INDIRANAGAR  Project_498        SNN Raj
# 99999  PROP100000        hennur road  Project_499        Embassy
#
#        Unit_Size_Sqft Configuration  Ticket_Price_Cr Transaction_Type  \
# 0              4025.0          4bhk        12.750846          Primary
# ...

# %%
#  Fill missing values

df['Unit_Size_Sqft'] = df['Unit_Size_Sqft'].fillna(df['Unit_Size_Sqft'].mean())
df['Ticket_Price_Cr'] = df['Ticket_Price_Cr'].fillna(df['Ticket_Price_Cr'].mean())
df['Amenity_Score'] = df['Amenity_Score'].fillna(df['Amenity_Score'].median())
df['Buyer_Comments'] = df['Buyer_Comments'].fillna("No Comments")
df
# Out:
#       Property_ID       Micro_Market Project_Name Developer_Name  \
# 0      PROP000001      Sarjapur Road    Project_0            RMZ
# 1      PROP000002        Indiranagar    Project_1    Puravankara
# 2      PROP000003  Bannerghatta Road    Project_2   Tata Housing
# 3      PROP000004       bellary road    Project_3        Embassy
# 4      PROP000005        Koramangala    Project_4        SNN Raj
# ...           ...                ...          ...            ...
# 99995  PROP099996       bellary road  Project_495     L&T Realty
# 99996  PROP099997          YELAHANKA  Project_496     L&T Realty
# 99997  PROP099998        rajajinagar  Project_497       Prestige
# 99998  PROP099999        INDIRANAGAR  Project_498        SNN Raj
# 99999  PROP100000        hennur road  Project_499        Embassy
#
#        Unit_Size_Sqft Configuration  Ticket_Price_Cr Transaction_Type  \
# 0              4025.0          4bhk        12.750846          Primary
# ...

# %%
df.isnull().sum()
# Out:
# Property_ID             0
# Micro_Market            0
# Project_Name            0
# Developer_Name          0
# Unit_Size_Sqft          0
# Configuration           0
# Ticket_Price_Cr         0
# Transaction_Type        0
# Buyer_Type              0
# Purchase_Quarter        0
# Connectivity_Score      0
# Amenity_Score           0
# Possession_Status       0
# Sales_Channel           0
# NRI_Buyer               0
# Locality_Infra_Score    0
# Avg_Traffic_Time_Min    0
# Buyer_Comments          0
# dtype: int64

# %%
df['Buyer_Type'] = df['Buyer_Type'].replace({'Other':'OTHERS','Startup Founder':'STARTUP FOUNDER'})
df['Micro_Market'] = df['Micro_Market'].str.title()
df['Possession_Status'] = df['Possession_Status'].str.title()
df['NRI_Buyer'] = df['NRI_Buyer'].str.title()
df['Configuration'] = df['Configuration'].str.upper()
df.rename(columns={"Developer_Name": "Builder"}, inplace=True)
df
# Out:
#       Property_ID       Micro_Market Project_Name       Builder  \
# 0      PROP000001      Sarjapur Road    Project_0           RMZ
# 1      PROP000002        Indiranagar    Project_1   Puravankara
# 2      PROP000003  Bannerghatta Road    Project_2  Tata Housing
# 3      PROP000004       Bellary Road    Project_3       Embassy
# 4      PROP000005        Koramangala    Project_4       SNN Raj
# ...           ...                ...          ...           ...
# 99995  PROP099996       Bellary Road  Project_495    L&T Realty
# 99996  PROP099997          Yelahanka  Project_496    L&T Realty
# 99997  PROP099998        Rajajinagar  Project_497      Prestige
# 99998  PROP099999        Indiranagar  Project_498       SNN Raj
# 99999  PROP100000        Hennur Road  Project_499       Embassy
#
#        Unit_Size_Sqft Configuration  Ticket_Price_Cr Transaction_Type  \
# 0              4025.0          4BHK        12.750846          Primary
# ...

# %%
# Extract quarter column from 'Purchase_Quarter'
df['Purchase_Quarter'] = pd.to_datetime(df['Purchase_Quarter'])
df['Quarter_Number'] = df['Purchase_Quarter'].dt.quarter
df['Quarter_Number']
# Out:
# 0        1
# 1        2
# 2        4
# 3        1
# 4        4
#         ..
# 99995    4
# 99996    4
# 99997    3
# 99998    3
# 99999    3
# Name: Quarter_Number, Length: 100000, dtype: int32

# %%
# Calculate Price per Sqft
df["Price_per_Sqft"] = df["Ticket_Price_Cr"] * 10000000 / df["Unit_Size_Sqft"]
df
# Out:
#       Property_ID       Micro_Market Project_Name       Builder  \
# 0      PROP000001      Sarjapur Road    Project_0           RMZ
# 1      PROP000002        Indiranagar    Project_1   Puravankara
# 2      PROP000003  Bannerghatta Road    Project_2  Tata Housing
# 3      PROP000004       Bellary Road    Project_3       Embassy
# 4      PROP000005        Koramangala    Project_4       SNN Raj
# ...           ...                ...          ...           ...
# 99995  PROP099996       Bellary Road  Project_495    L&T Realty
# 99996  PROP099997          Yelahanka  Project_496    L&T Realty
# 99997  PROP099998        Rajajinagar  Project_497      Prestige
# 99998  PROP099999        Indiranagar  Project_498       SNN Raj
# 99999  PROP100000        Hennur Road  Project_499       Embassy
#
#        Unit_Size_Sqft Configuration  Ticket_Price_Cr Transaction_Type  \
# 0              4025.0          4BHK        12.750846          Primary
# ...

# %%
# Create Booking_Flag column usind Transaction_Type
df['Booking_Flag'] = df['Transaction_Type'].str.lower().apply(lambda x: 1 if x == 'primary' else 0 if x == 'secondary' else None)
df
# Out:
#       Property_ID       Micro_Market Project_Name       Builder  \
# 0      PROP000001      Sarjapur Road    Project_0           RMZ
# 1      PROP000002        Indiranagar    Project_1   Puravankara
# 2      PROP000003  Bannerghatta Road    Project_2  Tata Housing
# 3      PROP000004       Bellary Road    Project_3       Embassy
# 4      PROP000005        Koramangala    Project_4       SNN Raj
# ...           ...                ...          ...           ...
# 99995  PROP099996       Bellary Road  Project_495    L&T Realty
# 99996  PROP099997          Yelahanka  Project_496    L&T Realty
# 99997  PROP099998        Rajajinagar  Project_497      Prestige
# 99998  PROP099999        Indiranagar  Project_498       SNN Raj
# 99999  PROP100000        Hennur Road  Project_499       Embassy
#
#        Unit_Size_Sqft Configuration  Ticket_Price_Cr Transaction_Type  \
# 0              4025.0          4BHK        12.750846          Primary
# ...

# %%
# !pip install sqlalchemy pymysql
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\Vijay\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
#from sqlalchemy import create_engine

#engine = create_engine("mysql+pymysql://root:Ramkrish9159981599@localhost:3306/housing_sales_db")

# %%
#Insert data into SQL table

#df.to_sql("luxury_housing", engine, if_exists="replace", index=False)

# %%
df.columns
# Out:
# Index(['Property_ID', 'Micro_Market', 'Project_Name', 'Builder',
#        'Unit_Size_Sqft', 'Configuration', 'Ticket_Price_Cr',
#        'Transaction_Type', 'Buyer_Type', 'Purchase_Quarter',
#        'Connectivity_Score', 'Amenity_Score', 'Possession_Status',
#        'Sales_Channel', 'NRI_Buyer', 'Locality_Infra_Score',
#        'Avg_Traffic_Time_Min', 'Buyer_Comments', 'Quarter_Number',
#        'Price_per_Sqft', 'Booking_Flag'],
#       dtype='object')
